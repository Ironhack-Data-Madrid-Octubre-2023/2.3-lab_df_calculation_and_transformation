# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import re

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from [kaggle](https://www.kaggle.com/abcsds/pokemon/) . Read the data into a dataframe called `pokemon`.

# %%
pokemon = pd.read_csv('Pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\blanx\ironhack\labs_clase\semana_2\dia_3\2.3-lab_df_calculation_and_transformation_Blanca\your-code\challenge-1.ipynb Celda 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/blanx/ironhack/labs_clase/semana_2/dia_3/2.3-lab_df_calculation_and_transformation_Blanca/your-code/challenge-1.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> pokemon.corr()
#
# File c:\Users\blanx\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\blanx\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\blanx\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\blanx\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Bulbasaur'

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
pd.concat([pokemon['Type 1'], pokemon['Type 2']]).unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
'''
def limpiar_nombres(nombres):
    for nombre in nombres:
        nombres = nombres.lower()
        
        if 'mega' in nombre[0]:
            return nombre[0]
        elif 'mega' in nombre[1]:
            return nombre[1]
        elif 'mega' not in nombre:
            return nombre[0:1]
        else:
            return nombre[0:1]
'''

pokemon['Name'] = pokemon['Name'].str.replace('.*Mega', 'Mega', regex=True)

# %%
pokemon['Name'][:50]
# Out:
# 0            Bulbasaur
# 1              Ivysaur
# 2             Venusaur
# 3        Mega Venusaur
# 4           Charmander
# 5           Charmeleon
# 6            Charizard
# 7     Mega Charizard X
# 8     Mega Charizard Y
# 9             Squirtle
# 10           Wartortle
# 11           Blastoise
# 12      Mega Blastoise
# 13            Caterpie
# 14             Metapod
# 15          Butterfree
# 16              Weedle
# 17              Kakuna
# 18            Beedrill
# 19       Mega Beedrill
# 20              Pidgey
# 21           Pidgeotto
# 22             Pidgeot
# 23        Mega Pidgeot
# 24             Rattata
# 25            Raticate
# 26             Spearow
# 27              Fearow
# 28               Ekans
# 29               Arbok
# 30             Pikachu
# 31              Raichu
# 32           Sandshrew
# 33           Sandslash
# 34            Nidoran♀
# 35            Nidorina
# 36           Nidoqueen
# 37            Nidoran♂
# 38            Nidorino
# 39            Nidoking
# 40            Clefairy
# 41            Clefable
# 42              Vulpix
# 43           Ninetales
# 44          Jigglypuff
# 45          Wigglytuff
# 46               Zubat
# 47              Golbat
# 48              Oddish
# 49               Gloom
# Name: Name, dtype: object

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
#`A/D Ratio` = `Attack` / `Defense`.

A_D_Ratio = pokemon['Attack']/pokemon['Defense']
pokemon['A/D Ratio'] = A_D_Ratio 

pokemon.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65     45           1      False   1.000000
# 1       80     60           1      False   0.984127
# 2      100     80           1      False   0.987952
# 3      120     80           1      False   0.813008
# 4       50     65           1      False   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
pokemon[pokemon['A/D Ratio']==pokemon['A/D Ratio'].max()]['Name']
# Out:
# 429    DeoxysAttack Forme
# Name: Name, dtype: object

# %%
pokemon['A/D Ratio'].max()
# Out:
# 9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
pokemon['A/D Ratio'].min()
# Out:
# 0.043478260869565216

# %%
pokemon[pokemon['A/D Ratio']==pokemon['A/D Ratio'].min()]['Name']
# Out:
# 230    Shuckle
# Name: Name, dtype: object

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
'''
Combo_Type = pokemon['Type 1'] + pokemon['Type 2']
pokemon['Combo Type'] = Combo_Type
'''
'''
#if Combo_Type['Type 1'] + Combo_Type['Type 2']:

if Combo_Type = ['Type 1'] + ['Type 2']:
    return pokemon['Type 1'] + '-' + pokemon['Type 2']
else:
    return pokemon['Type 1']

#pokemon['Type 1'], ['Type 2']
# usar nan para quitar nulos

pokemon['Type 2'].isna()
'''

for i in range(len(pokemon)):
    if type(pokemon["Type 2"][i]) == float:
        pokemon['Combo Type'][i] = pokemon["Type 1"][i]
    else:
        pokemon['Combo Type'][i] = pokemon["Type 1"][i] + "-" + pokemon["Type 2"][i]

pokemon.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\blanx\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Combo Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\blanx\ironhack\labs_clase\semana_2\dia_3\2.3-lab_df_calculation_and_transformation_Blanca\your-code\challenge-1.ipynb Celda 23 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/blanx/ironhack/labs_clase/semana_2/dia_3/2.3-lab_df_calculation_and_transformation_Blanca/your-code/challenge-1.ipynb#X31sZmlsZQ%3D%3D?line=20'>21</a>         pokemon['Combo Type'][i] = pokemon["Type 1"][i]
#      <a href='vscode-notebook-cell:/c%3A/Users/blanx/ironhack/labs_clase/semana_2/dia_3/2.3-lab_df_calculation_and_transformation_Blanca/your-code/challenge-1.ipynb#X31sZmlsZQ%3D%3D?line=21'>22</a>     else:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/blanx/ironhack/labs_clase/semana_2/dia_3/2.3-lab_df_calculation_and_transformation_Blanca/your-code/challenge-1.ipynb#X31sZmlsZQ%3D%3D?line=22'>23</a>         pokemon['Combo Type'][i] = pokemon["Type 1"][i] + "-" + pokemon["Type 2"][i]
#      <a href='vscode-notebook-cell:/c%3A/Users/blanx/ironhack/labs_clase/semana_2/dia_3/2.3-lab_df_calculation_and_transformation_Blanca/your-code/challenge-1.ipynb#X31sZmlsZQ%3D%3D?line=24'>25</a> pokemon.head(5)
#
# File c:\Users\blanx\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Users\blanx\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Combo Type'

# %%
pokemon['Combo Type'].fillna(pokemon["Type 1"])
# Out:
# 0       Grass-Poison
# 1       Grass-Poison
# 2       Grass-Poison
# 3       Grass-Poison
# 4               Fire
#            ...
# 795       Rock-Fairy
# 796       Rock-Fairy
# 797    Psychic-Ghost
# 798     Psychic-Dark
# 799       Fire-Water
# Name: Combo Type, Length: 800, dtype: object

# %%
pokemon['Combo Type'] = pokemon["Type 1"] + "-" + pokemon["Type 2"]
pokemon['Combo Type'].fillna(pokemon["Type 1"], inplace=True)
pokemon
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# 3      3        Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4           Charmander     Fire     NaN    309  39      52       43
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 795  719              Diancie     Rock   Fairy    600  50     100      150
# 796  719         Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A_D_Ratio  A/D Ratio  \
# 0         65       65     45           1      False   1.000000   1.000000
# 1         80       80     60           1      False   0.984127   0.984127
# 2        100      100     80           1      False   0.987952   0.987952
# 3        122      120     80           1      False   0.813008   0.813008
# 4         60       50     65           1      False   1.209302   1.209302
# ..       ...      ...    ...         ...        ...        ...        ...
# 795      100      150     50           6       True   0.666667   0.666667
# 796      160      110    110           6       True   1.454545   1.454545
# 797      150      130     70           6       True   1.833333   1.833333
# 798      170      130     80           6       True   2.666667   2.666667
# 799      130       90     70           6       True   0.916667   0.916667
#
#         Combo Type
# 0     Grass-Poison
# 1     Grass-Poison
# 2     Grass-Poison
# 3     Grass-Poison
# 4             Fire
# ..             ...
# 795     Rock-Fairy
# 796     Rock-Fairy
# 797  Psychic-Ghost
# 798   Psychic-Dark
# 799     Fire-Water
#
# [800 rows x 16 columns]

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
per_95 = np.percentile(pokemon['A/D Ratio'], 95)
print (per_95)
# Out:
# 2.0

# %%
pokemon[pokemon['A/D Ratio']>per_95]
# Out:
#        #                     Name    Type 1  Type 2  Total   HP  Attack  \
# 18    15                 Beedrill       Bug  Poison    395   65      90
# 19    15            Mega Beedrill       Bug  Poison    495   65     150
# 44    39               Jigglypuff    Normal   Fairy    270  115      45
# 55    50                  Diglett    Ground     NaN    265   10      55
# 61    56                   Mankey  Fighting     NaN    305   40      80
# 75    69               Bellsprout     Grass  Poison    300   50      75
# 114  106                Hitmonlee  Fighting     NaN    455   50     120
# 147  136                  Flareon      Fire     NaN    525   65     130
# 164  150            Mega Mewtwo Y   Psychic     NaN    780  106     150
# 186  172                    Pichu  Electric     NaN    205   20      40
# 213  198                  Murkrow      Dark  Flying    405   60      85
# 259  240                    Magby      Fire     NaN    365   45      75
# 317  293                  Whismur    Normal     NaN    240   64      51
# 347  318                 Carvanha     Water    Dark    305   45      90
# 348  319                 Sharpedo     Water    Dark    460   70     120
# 359  328                 Trapinch    Ground     NaN    290   45     100
# 362  331                   Cacnea     Grass     NaN    335   50      85
# 385  353                  Shuppet     Ghost     NaN    295   44      75
# 387  354             Mega Banette     Ghost     NaN    555   64     165
# 392  359                    Absol      Dark     NaN    465   65     130
# 393  359               Mega Absol      Dark     NaN    565   65     150
# 428  386       DeoxysNormal Forme   Psychic     NaN    600   50     150
# 429  386       DeoxysAttack Forme   Psychic     NaN    600   50     180
# 453  408                 Cranidos      Rock     NaN    350   67     125
# 454  409                Rampardos      Rock     NaN    495   97     165
# 478  430                Honchkrow      Dark  Flying    505  100     125
# 495  446                 Munchlax    Normal     NaN    390  135      85
# 588  529                  Drilbur    Ground     NaN    328   60      85
# 589  530                Excadrill    Ground   Steel    508  110     135
# 611  551                  Sandile    Ground    Dark    292   50      72
# 615  555  DarmanitanStandard Mode      Fire     NaN    480  105     140
# 627  566                   Archen      Rock  Flying    401   55     112
# 628  567                 Archeops      Rock  Flying    567   75     140
# 681  620                 Mienshao  Fighting     NaN    510   65     125
# 750  681     AegislashBlade Forme     Steel   Ghost    520   60     150
# 798  720       HoopaHoopa Unbound   Psychic    Dark    680   80     160
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  A_D_Ratio  \
# 18        40       45       80     75           1      False   2.250000
# 19        40       15       80    145           1      False   3.750000
# 44        20       45       25     20           1      False   2.250000
# 55        25       35       45     95           1      False   2.200000
# 61        35       35       45     70           1      False   2.285714
# 75        35       70       30     40           1      False   2.142857
# 114       53       35      110     87           1      False   2.264151
# 147       60       95      110     65           1      False   2.166667
# 164       70      194      120    140           1       True   2.142857
# 186       15       35       35     60           2      False   2.666667
# 213       42       85       42     91           2      False   2.023810
# 259       37       70       55     83           2      False   2.027027
# 317       23       51       23     28           3      False   2.217391
# 347       20       65       20     65           3      False   4.500000
# 348       40       95       40     95           3      False   3.000000
# 359       45       45       45     10           3      False   2.222222
# 362       40       85       40     35           3      False   2.125000
# 385       35       63       33     45           3      False   2.142857
# 387       75       93       83     75           3      False   2.200000
# 392       60       75       60     75           3      False   2.166667
# 393       60      115       60    115           3      False   2.500000
# 428       50      150       50    150           3       True   3.000000
# 429       20      180       20    150           3       True   9.000000
# 453       40       30       30     58           4      False   3.125000
# 454       60       65       50     58           4      False   2.750000
# 478       52      105       52     71           4      False   2.403846
# 495       40       40       85      5           4      False   2.125000
# 588       40       30       45     68           5      False   2.125000
# 589       60       50       65     88           5      False   2.250000
# 611       35       35       35     65           5      False   2.057143
# 615       55       30       55     95           5      False   2.545455
# 627       45       74       45     70           5      False   2.488889
# 628       65      112       65    110           5      False   2.153846
# 681       60       95       60    105           5      False   2.083333
# 750       50      150       50     60           6      False   3.000000
# 798       60      170      130     80           6       True   2.666667
#
#      A/D Ratio    Combo Type
# 18    2.250000    Bug-Poison
# 19    3.750000    Bug-Poison
# 44    2.250000  Normal-Fairy
# 55    2.200000        Ground
# 61    2.285714      Fighting
# 75    2.142857  Grass-Poison
# 114   2.264151      Fighting
# 147   2.166667          Fire
# 164   2.142857       Psychic
# 186   2.666667      Electric
# 213   2.023810   Dark-Flying
# 259   2.027027          Fire
# 317   2.217391        Normal
# 347   4.500000    Water-Dark
# 348   3.000000    Water-Dark
# 359   2.222222        Ground
# 362   2.125000         Grass
# 385   2.142857         Ghost
# 387   2.200000         Ghost
# 392   2.166667          Dark
# 393   2.500000          Dark
# 428   3.000000       Psychic
# 429   9.000000       Psychic
# 453   3.125000          Rock
# 454   2.750000          Rock
# 478   2.403846   Dark-Flying
# 495   2.125000        Normal
# 588   2.125000        Ground
# 589   2.250000  Ground-Steel
# 611   2.057143   Ground-Dark
# 615   2.545455          Fire
# 627   2.488889   Rock-Flying
# 628   2.153846   Rock-Flying
# 681   2.083333      Fighting
# 750   3.000000   Steel-Ghost
# 798   2.666667  Psychic-Dark

# %%
sorted_pokemon = pokemon[pokemon['A/D Ratio'] > per_95].sort_values(by='A/D Ratio', ascending=False).head(5)
print(sorted_pokemon)
# Out:
#        #                  Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386    DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318              Carvanha    Water    Dark    305  45      90       20
# 19    15         Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408              Cranidos     Rock     NaN    350  67     125       40
# 750  681  AegislashBlade Forme    Steel   Ghost    520  60     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A_D_Ratio  A/D Ratio  \
# 429      180       20    150           3       True      9.000      9.000
# 347       65       20     65           3      False      4.500      4.500
# 19        15       80    145           1      False      3.750      3.750
# 453       30       30     58           4      False      3.125      3.125
# 750      150       50     60           6      False      3.000      3.000
#
#       Combo Type
# 429      Psychic
# 347   Water-Dark
# 19    Bug-Poison
# 453         Rock
# 750  Steel-Ghost

# %%
pokemon.sort_values(by='A/D Ratio', ascending=False).head(5)
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A_D_Ratio  A/D Ratio  \
# 429      180       20    150           3       True      9.000      9.000
# 347       65       20     65           3      False      4.500      4.500
# 19        15       80    145           1      False      3.750      3.750
# 453       30       30     58           4      False      3.125      3.125
# 348       95       40     95           3      False      3.000      3.000
#
#      Combo Type
# 429     Psychic
# 347  Water-Dark
# 19   Bug-Poison
# 453        Rock
# 348  Water-Dark

# %%
top5 = pokemon.sort_values(by='A/D Ratio', ascending=False).head(5)
print(top5)
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A_D_Ratio  A/D Ratio  \
# 429      180       20    150           3       True      9.000      9.000
# 347       65       20     65           3      False      4.500      4.500
# 19        15       80    145           1      False      3.750      3.750
# 453       30       30     58           4      False      3.125      3.125
# 348       95       40     95           3      False      3.000      3.000
#
#      Combo Type
# 429     Psychic
# 347  Water-Dark
# 19   Bug-Poison
# 453        Rock
# 348  Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
#top5 = pokemon.sort_values(by='A/D Ratio', ascending=False).head(5)

mi_lista = top5["Combo Type"]
nueva_lista = mi_lista.tolist()
nueva_lista
# Out:
# ['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock', 'Water-Dark']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
top5.groupby(['Combo Type']).mean(numeric_only=True)
# Out:
#                 #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Combo Type
# Bug-Poison   15.0  495.0  65.0   150.0     40.0     15.0     80.0  145.0
# Psychic     386.0  600.0  50.0   180.0     20.0    180.0     20.0  150.0
# Rock        408.0  350.0  67.0   125.0     40.0     30.0     30.0   58.0
# Water-Dark  318.5  382.5  57.5   105.0     30.0     80.0     30.0   80.0
#
#             Generation  Legendary  A_D_Ratio  A/D Ratio
# Combo Type
# Bug-Poison         1.0        0.0      3.750      3.750
# Psychic            3.0        1.0      9.000      9.000
# Rock               4.0        0.0      3.125      3.125
# Water-Dark         3.0        0.0      3.750      3.750
