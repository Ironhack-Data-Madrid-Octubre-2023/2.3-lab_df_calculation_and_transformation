# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from [kaggle](https://www.kaggle.com/abcsds/pokemon/) . Read the data into a dataframe called `pokemon`.

# %%
# %pip install xlwt
# %pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlwt
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/100.0 kB ? eta -:--:--
#      --------------- --------------------- 41.0/100.0 kB 487.6 kB/s eta 0:00:01
#      ------------------------------------ 100.0/100.0 kB 954.7 kB/s eta 0:00:00
# Installing collected packages: xlwt
# Successfully installed xlwt-1.3.0
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xlrd in c:\users\álvaro\appdata\roaming\python\python311\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
path = 'C:\\Users\\Álvaro\\Desktop\\ironhack\\2.3-lab_df_calculation_and_transformation\\your-code\\pokemon.csv'
pokemon = pd.read_csv(path)
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
tipo1 = pokemon ['Type 1'].values
tipo2 = pokemon ['Type 2'].values

tipos = np.array([tipo1, tipo2])
tipos
# Out:
# array([['Grass', 'Grass', 'Grass', ..., 'Psychic', 'Psychic', 'Fire'],
#        ['Poison', 'Poison', 'Poison', ..., 'Ghost', 'Dark', 'Water']],
#       dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
string = "CharizardMega Charizard X"
def mega_correction(string):
    #todo a minuscula para que no se lie
    string = string.lower()
    if “mega” in string:
        # separamos en palabras
        string = string.split()
        # quitamos la palabra si tiene “mega”
        for i in string:
            if “mega” in i: string.remove(i)
        # juntamos con el join para que sea string
        string = ” “.join(string)
        # añadimos mega al principio
        string = “mega ” + string
        # De vuelta a maysuculas:
        string = string.title()
    return string
mega_correction(string)
# Out:
#   Cell In[73], line 1
#     string = “CharizardMega Charizard X”
#              ^
# SyntaxError: invalid character '“' (U+201C)

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
pokemon['A/D Ratio'] = pokemon['Attack']/ pokemon['Defense']
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary          Types  A/D Ratio
# 0         65       65     45           1      False   Grass-Poison   1.000000
# 1         80       80     60           1      False   Grass-Poison   0.984127
# 2        100      100     80           1      False   Grass-Poison   0.987952
# 3        122      120     80           1      False   Grass-Poison   0.813008
# 4         60       50     65           1      False            NaN   1.209302
# ..       ...      ...    ...         ...        ...            ...        ...
# 795      100      150     50           6       True     Rock-Fairy   0.666667
# 796      160      110    110           6       True     Rock-Fairy   1.454545
# 797      150      130     70           6       True  Psychic-Ghost   1.833333
# 798      170      130     80           6       True   Psychic-Dark   2.666667
# 799      130       90     70           6       True     Fire-Water   0.916667
#
# [800 rows x 15 columns]

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
pokemon_max_ad_ratio = pokemon['A/D Ratio'].max()

pokemon_max_ad_ratio
# Out:
# 9.0

# %%
valor_buscar = pokemon_max_ad_ratio

nombre_max_ad = pokemon.loc[pokemon['A/D Ratio'] == valor_buscar, 'Name'].values[0]

nombre_max_ad
# Out:
# 'DeoxysAttack Forme'

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
pokemon_min_ad_ratio = pokemon['A/D Ratio'].min()

valor_buscar = pokemon_min_ad_ratio

nombre_min_ad = pokemon.loc[pokemon['A/D Ratio'] == valor_buscar, 'Name'].values[0]

nombre_min_ad
# Out:
# 'Shuckle'

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
def tipos (a,b):
    if pd.notna(b):
        return a + '-' + b
    else:
        return a
    
pokemon['Combo Type'] = pokemon.apply(lambda row: tipos(row['Type 1'], row['Type 2']), axis=1)
pokemon
# Out:
#        #                           Name   Type 1  Type 2  Total  HP  Attack  \
# 0      1                      Bulbasaur    Grass  Poison    318  45      49
# 1      2                        Ivysaur    Grass  Poison    405  60      62
# 2      3                       Venusaur    Grass  Poison    525  80      82
# 3      3  MegaMegavenusaurmega Venusaur    Grass  Poison    625  80     100
# 4      4                     Charmander     Fire     NaN    309  39      52
# ..   ...                            ...      ...     ...    ...  ..     ...
# 795  719                        Diancie     Rock   Fairy    600  50     100
# 796  719    MegaMegadianciemega Diancie     Rock   Fairy    700  50     160
# 797  720            HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720             HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                      Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary          Types  \
# 0         49       65       65     45           1      False   Grass-Poison
# 1         63       80       80     60           1      False   Grass-Poison
# 2         83      100      100     80           1      False   Grass-Poison
# 3        123      122      120     80           1      False   Grass-Poison
# 4         43       60       50     65           1      False            NaN
# ..       ...      ...      ...    ...         ...        ...            ...
# 795      150      100      150     50           6       True     Rock-Fairy
# 796      110      160      110    110           6       True     Rock-Fairy
# 797       60      150      130     70           6       True  Psychic-Ghost
# 798       60      170      130     80           6       True   Psychic-Dark
# 799      120      130       90     70           6       True     Fire-Water
#
#      A/D Ratio     Combo Type
# 0     1.000000   Grass-Poison
# 1     0.984127   Grass-Poison
# 2     0.987952   Grass-Poison
# 3     0.813008   Grass-Poison
# 4     1.209302           Fire
# ..         ...            ...
# 795   0.666667     Rock-Fairy
# 796   1.454545     Rock-Fairy
# 797   1.833333  Psychic-Ghost
# 798   2.666667   Psychic-Dark
# 799   0.916667     Fire-Water
#
# [800 rows x 16 columns]

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
top_5 = pokemon.nlargest(5, 'A/D Ratio')

top_5
# Out:
#        #                           Name   Type 1  Type 2  Total  HP  Attack  \
# 429  386             DeoxysAttack Forme  Psychic     NaN    600  50     180
# 347  318                       Carvanha    Water    Dark    305  45      90
# 19    15  MegaMegabeedrillmega Beedrill      Bug  Poison    495  65     150
# 453  408                       Cranidos     Rock     NaN    350  67     125
# 348  319                       Sharpedo    Water    Dark    460  70     120
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary       Types  \
# 429       20      180       20    150           3       True         NaN
# 347       20       65       20     65           3      False  Water-Dark
# 19        40       15       80    145           1      False  Bug-Poison
# 453       40       30       30     58           4      False         NaN
# 348       40       95       40     95           3      False  Water-Dark
#
#      A/D Ratio  Combo Type
# 429      9.000     Psychic
# 347      4.500  Water-Dark
# 19       3.750  Bug-Poison
# 453      3.125        Rock
# 348      3.000  Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
lista = top_5['Combo Type'].values
lista
# Out:
# array(['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock', 'Water-Dark'],
#       dtype=object)

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Types',
#        'A/D Ratio', 'Combo Type'],
#       dtype='object')

# %%
grouped = pokemon.groupby('Combo Type')
filas_interes = ['Bug-Poison', 'Psychic', 'Rock', 'Water-Dark']

media = grouped.get_group(filas_interes).mean()  # Reemplaza 'Bug-Poison' con las filas de interés
media = media.to_frame().T
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 4
#       1 grouped = pokemon.groupby('Combo Type')
#       2 filas_interes = ['Bug-Poison', 'Psychic', 'Rock', 'Water-Dark']
# ----> 4 media = grouped.get_group(filas_interes).mean()  # Reemplaza 'Bug-Poison' con las filas de interés
#       5 media = media.to_frame().T
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1057, in BaseGroupBy.get_group(self, name, obj)
#     987 @final
#     988 def get_group(self, name, obj=None) -> DataFrame | Series:
#     989     """
#     990     Construct DataFrame from group with provided name.
#     991
#    (...)
#    1055     dtype: int64
#    1056     """
# -> 1057     inds = self._get_index(name)
#    1058     if not len(inds):
#    1059         raise KeyError(name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:929, in BaseGroupBy._get_index(self, name)
#     924 @final
#     925 def _get_index(self, name):
#     926     """
#     927     Safe get index, translate keys for datelike to underlying repr.
#     928     """
# --> 929     return self._get_indices([name])[0]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:922, in BaseGroupBy._get_indices(self, names)
#     919     converter = get_converter(index_sample)
#     920     names = (converter(name) for name in names)
# --> 922 return [self.indices.get(name, []) for name in names]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:922, in <listcomp>(.0)
#     919     converter = get_converter(index_sample)
#     920     names = (converter(name) for name in names)
# --> 922 return [self.indices.get(name, []) for name in names]
#
# TypeError: unhashable type: 'list'

# %%
grouped = pokemon.groupby('Combo Type')

columnas_numericas = ["#",'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'A/D Ratio']

grouped[columnas_numericas].mean()
# Out:
#                         #       Total         HP      Attack     Defense  \
# Combo Type
# Bug            361.352941  289.705882  53.058824   50.352941   55.411765
# Bug-Electric   595.500000  395.500000  60.000000   62.000000   55.000000
# Bug-Fighting   214.000000  550.000000  80.000000  155.000000   95.000000
# Bug-Fire       636.500000  455.000000  70.000000   72.500000   60.000000
# Bug-Flying     286.285714  419.500000  63.000000   70.142857   61.571429
# ...                   ...         ...        ...         ...         ...
# Water-Ice      103.000000  511.666667  90.000000   83.333333  113.333333
# Water-Poison   118.666667  426.666667  61.666667   68.333333   58.333333
# Water-Psychic  111.800000  481.000000  87.000000   73.000000  104.000000
# Water-Rock     430.000000  428.750000  70.750000   82.750000  112.750000
# Water-Steel    395.000000  530.000000  84.000000   86.000000   88.000000
#
#                   Sp. Atk     Sp. Def      Speed  Generation  Legendary  \
# Combo Type
# Bug             39.294118   43.647059  47.941176    3.470588        0.0
# Bug-Electric    77.000000   55.000000  86.500000    5.000000        0.0
# Bug-Fighting    40.000000  100.000000  80.000000    2.000000        0.0
# Bug-Fire        92.500000   80.000000  80.000000    5.000000        0.0
# Bug-Flying      72.857143   69.071429  82.857143    2.857143        0.0
# ...                   ...         ...        ...         ...        ...
# Water-Ice       80.000000   78.333333  66.666667    1.000000        0.0
# Water-Poison    61.666667   91.666667  85.000000    1.333333        0.0
# Water-Psychic   94.000000   79.000000  44.000000    1.200000        0.0
# Water-Rock      61.500000   65.000000  36.000000    3.750000        0.0
# Water-Steel    111.000000  101.000000  60.000000    4.000000        0.0
#
#                A/D Ratio
# Combo Type
# Bug             0.940179
# Bug-Electric    1.111667
# Bug-Fighting    1.637681
# Bug-Fire        1.234266
# Bug-Flying      1.146274
# ...                  ...
# Water-Ice       0.821759
# Water-Poison    1.162149
# Water-Psychic   0.783668
# Water-Rock      0.727170
# Water-Steel     0.977273
#
# [154 rows x 11 columns]
